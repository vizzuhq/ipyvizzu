# %%
import pandas as pd
from ipyvizzu import Chart, Data, Config, Style

# To setup:
#   pip install jupyterlab
#   mkdir ipyvizzu
#   cd ipyvizzu
#   pip install virtual env
#   mkdir venv
#   python -m venv venv
#   .\venv\Scripts\activate.bat
#   validate (venv) is prefixing your prompt
#   pip install pandas
#   pip install pyarrow
#   pip install ipyvizzu
#   jupyter lab
#

# %%
###( load dataset 1 )###
eu_df = pd.read_csv(
    "https://ipyvizzu.vizzuhq.com/0.18/assets/data/chart_types_eu.csv",
    dtype={
        "Year": str, 
        "Timeseries": str
    },
)
data_eu = Data()
data_eu.add_df(eu_df)


###( load dataset 2 )###
eu_6_df = pd.read_csv(
    "https://ipyvizzu.vizzuhq.com/0.18/assets/data/chart_types_eu_data_6.csv",
    dtype={
        "Year": str, 
        "Timeseries": str
    },
)
data_eu_6 = Data()
data_eu_6.add_df(eu_6_df)


###( load dataset 3 )###
eu_3_df = pd.read_csv(
    "https://ipyvizzu.vizzuhq.com/0.18/assets/data/chart_types_eu_data_3.csv",
    dtype={
        "Year": str, 
        "Timeseries": str
    },
)
data_eu_3 = Data()
data_eu_3.add_df(eu_3_df)


###( load dataset 4 )###
eu_4_df = pd.read_csv(
    "https://ipyvizzu.vizzuhq.com/0.18/assets/data/chart_types_eu_data_4.csv",
    dtype={
        "Year": str, 
        "Timeseries": str
    },
)
data_eu_4 = Data()
data_eu_4.add_df(eu_4_df)


###( load dataset Music Industry History - 1 )###
mih_1_df = pd.read_csv(
    "https://ipyvizzu.vizzuhq.com/0.18/assets/data/music_industry_history_1.csv",
    dtype={
        "Year": str, 
        "Timeseries": str
    },
)
data_mih_1 = Data()
data_mih_1.add_df(mih_1_df)

# %%
###( Area Chart )###
### https://ipyvizzu.vizzuhq.com/latest/examples/analytical_operations/drilldown/area/

chart = Chart()
chart.animate(data_eu)
chart.animate(
    Config.area(
        {
            "x": "Year", 
            "y": "Value 5 (+/-)", 
            "title": "Area Chart"
        }
    )
)

# %%
###( Percentage Area Chart )###
### https://ipyvizzu.vizzuhq.com/latest/examples/presets/area_percentage_chart/

chart = Chart()
chart.animate(data_eu)
chart.animate(
    Config.percentageArea(
        {
            "x": "Year",
            "y": "Value 2 (+)",
            "stackedBy": "Country",
            "title": "Percentage Area Chart",
        }
    )
)

# %%
###( Splitted Area Chart )###
### https://ipyvizzu.vizzuhq.com/latest/examples/presets/area_splitted_chart/

chart = Chart()
chart.animate(data_eu_6)
chart.animate(
    Config.splittedArea(
        {
            "x": "Year",
            "y": "Value 2 (+)",
            "splittedBy": "Country",
            "title": "Splitted Area Chart",
        }
    )
)

# %%
###( Stacked Area Chart )###
### https://ipyvizzu.vizzuhq.com/latest/examples/presets/area_stacked_chart/

chart = Chart()
chart.animate(data_eu)
chart.animate(
    Config.stackedArea(
        {
            "x": "Year",
            "y": "Value 2 (+)",
            "stackedBy": "Country",
            "title": "Stacked Area Chart",
        }
    )
)

# %%
###( Bar Chart )###
### https://ipyvizzu.vizzuhq.com/latest/examples/presets/bar_chart/

chart = Chart()
chart.animate(data_eu_6)
chart.animate(
    Config.bar(
        {
            "x": "Value 5 (+/-)", 
            "y": "Country", 
            "title": "Bar Chart"
        }
    )
)

# %%
###( Grouped Bar Chart )###
### https://ipyvizzu.vizzuhq.com/latest/examples/presets/bar_grouped_chart/

chart = Chart()
chart.animate(data_eu_6)
chart.animate(
    Config.groupedBar(
        {
            "x": "Value 5 (+/-)",
            "y": "Country",
            "groupedBy": "Joy factors",
            "title": "Grouped Bar Chart",
        }
    )
)

# %%
###( Percentage Bar Chart )###
### https://ipyvizzu.vizzuhq.com/latest/examples/presets/bar_percentage_chart/

chart = Chart()
chart.animate(data_eu_6)
chart.animate(
    Config.percentageBar(
        {
            "x": "Value 2 (+)",
            "y": "Country",
            "stackedBy": "Joy factors",
            "title": "Percentage Bar Chart",
        }
    )
)

# %%
###( Radial Bar Chart )###
### https://ipyvizzu.vizzuhq.com/latest/examples/presets/bar_radial_chart/

chart = Chart()
chart.animate(data_eu_6)
chart.animate(
    Config.radialBar(
        {
            "angle": "Value 1 (+)",
            "radius": "Country",
            "title": "Radial Bar Chart",
        }
    )
)

# %%
###( Radial Stacked Bar Chart )###
### https://ipyvizzu.vizzuhq.com/latest/examples/presets/bar_radial_stacked_chart/

chart = Chart()
chart.animate(data_eu_6)
chart.animate(
    Config.radialStackedBar(
        {
            "angle": "Value 2 (+)",
            "radius": "Country",
            "stackedBy": "Joy factors",
            "title": "Radial Stacked Bar Chart",
        }
    )
)

# %%
###( Splitted Bar Chart )###
### https://ipyvizzu.vizzuhq.com/latest/examples/presets/bar_splitted_chart/

chart = Chart()
chart.animate(data_eu)
chart.animate(
    Config.splittedBar(
        {
            "x": "Value 2 (+)",
            "y": "Year",
            "splittedBy": "Joy factors",
            "title": "Splitted Bar Chart",
        }
    )
)

# %%
###( Stacked Bar Chart )###
### https://ipyvizzu.vizzuhq.com/latest/examples/presets/bar_stacked_chart/

chart = Chart()
chart.animate(data_eu_6)
chart.animate(
    Config.stackedBar(
        {
            "x": "Value 2 (+)",
            "y": "Country",
            "stackedBy": "Joy factors",
            "title": "Stacked Bar Chart",
        }
    )
)

# %%
###( Bubble Chart )###
### https://ipyvizzu.vizzuhq.com/latest/examples/presets/bubble_chart/

chart = Chart()
chart.animate(data_eu)
chart.animate(
    Config.bubble(
        {
            "size": "Value 5 (+/-)",
            "color": "Country_code",
            "title": "Bubble Chart",
        }
    )
)

# %%
###( Bubble Plot )###
### https://ipyvizzu.vizzuhq.com/latest/examples/presets/bubble_plot/

chart = Chart()
chart.animate(data_eu)
chart.animate(
    Config.bubbleplot(
        {
            "x": "Value 4 (+/-)",
            "y": "Value 5 (+/-)",
            "color": "Joy factors",
            "dividedBy": "Country",
            "size": "Value 3 (+)",
            "title": "Bubble Plot",
        }
    )
)

# %%
###( Stacked Bubble Chart )###
### https://ipyvizzu.vizzuhq.com/latest/examples/presets/bubble_stacked_chart/

chart = Chart()
chart.animate(data_eu)
chart.animate(
    Config.stackedBubble(
        {
            "size": "Value 2 (+)",
            "color": "Joy factors",
            "stackedBy": "Country_code",
            "title": "Stacked Bubble Chart",
        }
    )
)

# %%
###( Column Chart )###
### https://ipyvizzu.vizzuhq.com/latest/examples/presets/column_chart/

chart = Chart()
chart.animate(data_eu)
chart.animate(
    Config.column(
        {
            "x": "Joy factors",
            "y": "Value 2 (+)",
            "title": "Column Chart",
        }
    )
)

# %%
###( Grouped Column Chart )###
### https://ipyvizzu.vizzuhq.com/latest/examples/presets/column_grouped_chart/

chart = Chart()
chart.animate(data_eu_6)
chart.animate(
    Config.groupedColumn(
        {
            "x": "Country",
            "y": "Value 5 (+/-)",
            "groupedBy": "Joy factors",
            "title": "Grouped Column Chart",
        }
    )
)

# %%
###( Percentage Column Chart )###
### https://ipyvizzu.vizzuhq.com/latest/examples/presets/column_percentage_chart/

chart = Chart()
chart.animate(data_eu_6)
chart.animate(
    Config.percentageColumn(
        {
            "x": "Country",
            "y": "Value 2 (+)",
            "stackedBy": "Joy factors",
            "title": "Percentage Column Chart",
        }
    )
)

# %%
###( Polar Column Chart )###
### https://ipyvizzu.vizzuhq.com/latest/examples/presets/column_polar_chart/

chart = Chart()
chart.animate(data_eu)
chart.animate(
    Config.polarColumn(
        {
            "angle": "Joy factors",
            "radius": "Value 2 (+)",
            "title": "Polar Column Chart",
        }
    )
)

# %%
###( Polar Stacked Column Chart )###
### https://ipyvizzu.vizzuhq.com/latest/examples/presets/column_polar_stacked_chart/

chart = Chart()
chart.animate(data_eu_6)
chart.animate(
    Config.polarStackedColumn(
        {
            "angle": "Country",
            "radius": "Value 2 (+)",
            "stackedBy": "Joy factors",
            "title": "Polar Stacked Column Chart",
        }
    )
)

# %%
###( Splitted Column Chart )###
### https://ipyvizzu.vizzuhq.com/latest/examples/presets/column_splitted_chart/

chart = Chart()
chart.animate(data_eu)
chart.animate(
    Config.splittedColumn(
        {
            "x": "Year",
            "y": "Value 2 (+)",
            "splittedBy": "Joy factors",
            "title": "Splitted Column Chart",
        }
    )
)

# %%
###( Stacked Column Chart )###
### https://ipyvizzu.vizzuhq.com/latest/examples/presets/column_stacked_chart/

chart = Chart()
chart.animate(data_eu_6)
chart.animate(
    Config.stackedColumn(
        {
            "x": "Country",
            "y": "Value 2 (+)",
            "stackedBy": "Joy factors",
            "title": "Stacked Column Chart",
        }
    )
)

# %%
###( Donut Chart )###
### https://ipyvizzu.vizzuhq.com/latest/examples/presets/donut_chart/

chart = Chart()
chart.animate(data_eu)
chart.animate(
    Config.donut(
        {
            "angle": "Value 2 (+)",
            "stackedBy": "Joy factors",
            "title": "Donut Chart",
        }
    )
)

# %%
###( Nested Donut Chart )###
### https://ipyvizzu.vizzuhq.com/latest/examples/presets/donut_nested_chart/

chart = Chart()
chart.animate(data_eu_3)
chart.animate(
    Config.nestedDonut(
        {
            "angle": "Value 2 (+)",
            "stackedBy": "Joy factors",
            "radius": "Country",
            "title": "Nested Donut Chart",
        }
    ),
    Style(
        {
            "plot": {
                "marker": {
                    "rectangleSpacing": "0",
                    "borderWidth": 1,
                    "borderOpacity": 0,
                }
            }
        }
    ),
)

# %%
###( Heatmap )###
### https://ipyvizzu.vizzuhq.com/latest/examples/presets/heatmap/

chart = Chart()
chart.animate(data_eu_6)
chart.animate(
    Config.heatmap(
        {
            "x": "Year",
            "y": "Country_code",
            "lightness": "Value 3 (+)",
            "title": "Heatmap",
        }
    ),
    Style({"plot": {"marker": {"rectangleSpacing": 0}}}),
)

# %%
###( Line Chart )###
### https://ipyvizzu.vizzuhq.com/latest/examples/presets/line_chart/

chart = Chart()
chart.animate(data_eu_6)
chart.animate(
    Config.line(
        {
            "x": "Year",
            "y": "Value 6 (+/-)",
            "dividedBy": "Country",
            "title": "Line Chart",
        }
    )
)

# %%
###( Polar Line Chart )###
### https://ipyvizzu.vizzuhq.com/latest/examples/presets/line_polar_chart/

chart = Chart()
chart.animate(data_eu_6)
chart.animate(
    Config.polarLine(
        {
            "angle": "Year",
            "radius": "Value 2 (+)",
            "dividedBy": "Country",
            "title": "Polar Line Chart",
        }
    )
)

# %%
###( Vertical Line Chart )###
### https://ipyvizzu.vizzuhq.com/latest/examples/presets/line_vertical_chart/

chart = Chart()
chart.animate(data_eu_6)
chart.animate(
    Config.line(
        {
            "x": "Value 6 (+/-)",
            "y": "Year",
            "dividedBy": "Country",
            "title": "Vertical Line Chart",
        }
    )
)

# %%
###( Lollipop Chart )###
### https://ipyvizzu.vizzuhq.com/latest/examples/presets/lollipop_chart/

chart = Chart()
chart.animate(data_eu)
chart.animate(
    Config.lollipop(
        {"x": "Year", "y": "Value 1 (+)", "title": "Lollipop Chart"}
    )
)

# %%
###( Marimekko Chart )###
### https://ipyvizzu.vizzuhq.com/latest/examples/presets/marimekko_chart/

chart = Chart()
chart.animate(data_eu_4)
chart.animate(
    Config.marimekko(
        {
            "x": "Value 2 (+)",
            "y": "Value 3 (+)",
            "stackedBy": "Joy factors",
            "groupedBy": "Country",
            "title": "Marimekko Chart",
        }
    )
)

# %%
###( Stacked Mekko Chart )###
### https://ipyvizzu.vizzuhq.com/latest/examples/presets/mekko_stacked_chart/

chart = Chart()
chart.animate(data_eu_4)
chart.animate(
    Config.mekko(
        {
            "x": "Value 1 (+)",
            "y": "Value 2 (+)",
            "stackedBy": "Joy factors",
            "groupedBy": "Country",
            "title": "Stacked Mekko Chart",
        }
    )
)

# %%
###( Pie Chart )###
### https://ipyvizzu.vizzuhq.com/latest/examples/presets/pie_chart/

chart = Chart()
chart.animate(data_eu)
chart.animate(
    Config.pie(
        {
            "angle": "Value 2 (+)",
            "by": "Joy factors",
            "title": "Pie Chart",
        }
    )
)

# %%
###( Variable Radius Pie Chart )###
### https://ipyvizzu.vizzuhq.com/latest/examples/presets/pie_variable_radius_chart/

chart = Chart()
chart.animate(data_eu)
chart.animate(
    Config.variableRadiusPie(
        {
            "angle": "Value 2 (+)",
            "radius": "Value 1 (+)",
            "by": "Joy factors",
            "title": "Variable Radius Pie Chart",
        }
    )
)

# %%
###( Scatter Plot )###
### https://ipyvizzu.vizzuhq.com/latest/examples/presets/scatter_plot/

chart = Chart()
chart.animate(data_eu)
chart.animate(
    Config.scatter(
        {
            "x": "Value 6 (+/-)",
            "y": "Value 5 (+/-)",
            "dividedBy": "Year",
            "title": "Scatter Plot",
        }
    )
)

# %%
###( Polar Scatter Plot )###
### https://ipyvizzu.vizzuhq.com/latest/examples/presets/scatter_polar_plot/

chart = Chart()
chart.animate(data_eu)
chart.animate(
    Config.polarScatter(
        {
            "angle": "Value 3 (+)",
            "radius": "Value 2 (+)",
            "dividedBy": "Country",
            "title": "Polar Scatter Plot",
        }
    )
)

# %%
###( Stream Graph )###
### https://ipyvizzu.vizzuhq.com/latest/examples/presets/stream_graph/

chart = Chart()
chart.animate(data_mih_1)
chart.animate(
    Config.stream(
        {
            "x": "Year",
            "y": "Revenue",
            "stackedBy": "Format",
            "title": "Stream Graph",
        }
    ),
    Style(
        {
            "plot": {
                "yAxis": {"label": {"numberScale": "K, M, B, T"}},
                "xAxis": {"label": {"angle": "-45deg"}},
            }
        }
    ),
)

# %%
###( Vertical Stream Graph )###
### https://ipyvizzu.vizzuhq.com/latest/examples/presets/stream_vertical_graph/

chart = Chart()
chart.animate(data_mih_1)
chart.animate(
    Config.verticalStream(
        {
            "x": "Revenue",
            "y": "Year",
            "stackedBy": "Format",
            "title": "Vertical Stream Graph",
        }
    ),
    Style(
        {
            "plot": {
                "yAxis": {"label": {"numberScale": "K, M, B, T"}},
                "xAxis": {"label": {"angle": "-45deg"}},
            }
        }
    ),
)

# %%
###( Treemap )###
### https://ipyvizzu.vizzuhq.com/latest/examples/presets/treemap/

chart = Chart()
chart.animate(data_eu)
chart.animate(
    Config.treemap(
        {
            "size": "Value 2 (+)",
            "color": "Country_code",
            "title": "Treemap",
        }
    )
)

# %%
###( Stacked Treemap )###
### https://ipyvizzu.vizzuhq.com/latest/examples/presets/treemap_stacked/

chart = Chart()
chart.animate(data_eu)
chart.animate(
    Config.stackedTreemap(
        {
            "size": "Value 2 (+)",
            "color": "Joy factors",
            "title": "Stacked Treemap",
            "dividedBy": "Country_code",
        }
    )
)

# %%
###( Violin Graph )###
### https://ipyvizzu.vizzuhq.com/latest/examples/presets/violin_graph/

chart = Chart()
chart.animate(data_mih_1)
chart.animate(
    Config.violin(
        {
            "x": "Year",
            "y": "Revenue",
            "splittedBy": "Format",
            "title": "Violin Graph",
        }
    ),
    Style(
        {
            "plot": {
                "yAxis": {"label": {"numberScale": "K, M, B, T"}},
                "xAxis": {"label": {"angle": "-45deg"}},
            }
        }
    ),
)

# %%
###( Vertical Violin Graph )###
### https://ipyvizzu.vizzuhq.com/latest/examples/presets/violin_graph/

chart = Chart()
chart.animate(data_mih_1)
chart.animate(
    Config.verticalViolin(
        {
            "x": "Revenue",
            "y": "Year",
            "splittedBy": "Format",
            "title": "Vertical Violin Graph",
        }
    ),
    Style(
        {
            "plot": {
                "xAxis": {"interlacing": {"color": "#ffffff00"}},
                "yAxis": {"label": {"numberScale": "K, M, B, T"}},
            }
        }
    ),
)

# %%
###( Waterfall Chart )###
### https://ipyvizzu.vizzuhq.com/latest/examples/presets/waterfall_chart/

chart = Chart()
chart.animate(data_eu)
chart.animate(
    Config.waterfall(
        {
            "x": "Year",
            "y": "Value 5 (+/-)",
            "title": "Waterfall Chart",
        }
    ),
    Style(
        {
            "plot": {
                "marker": {
                    "colorGradient": "#ff001b 0,#ff001b 0.5,#7e79e8 0.5,#7e79e8 1",
                    "label": {"position": "top"},
                }
            }
        }
    ),
)

# %%
###( END )###
