# %%
import pandas as pd
from ipyvizzu import Chart, Data, Config, Style

# To setup:
#   pip install jupyterlab
#   mkdir ipyvizzu
#   cd ipyvizzu
#   pip install virtual env
#   mkdir venv
#   python -m venv venv
#   .\venv\Scripts\activate.bat
#   validate (venv) is prefixing your prompt
#   pip install pandas
#   pip install pyarrow
#   pip install ipyvizzu
#   jupyter lab
#

# %%
###( load dataset 1 )###
eu_df = pd.read_csv(
    "https://ipyvizzu.vizzuhq.com/0.17/assets/data/chart_types_eu.csv",
    dtype={
        "Year": str, 
        "Timeseries": str
    },
)
data_eu = Data()
data_eu.add_df(eu_df)


###( load dataset 2 )###
eu_6_df = pd.read_csv(
    "https://ipyvizzu.vizzuhq.com/0.17/assets/data/chart_types_eu_data_6.csv",
    dtype={
        "Year": str, 
        "Timeseries": str
    },
)
data_eu_6 = Data()
data_eu_6.add_df(eu_6_df)


###( load dataset 3 )###
eu_3_df = pd.read_csv(
    "https://ipyvizzu.vizzuhq.com/0.17/assets/data/chart_types_eu_data_3.csv",
    dtype={
        "Year": str, 
        "Timeseries": str
    },
)
data_eu_3 = Data()
data_eu_3.add_df(eu_3_df)


###( load dataset 4 )###
eu_4_df = pd.read_csv(
    "https://ipyvizzu.vizzuhq.com/0.17/assets/data/chart_types_eu_data_4.csv",
    dtype={
        "Year": str, 
        "Timeseries": str
    },
)
data_eu_4 = Data()
data_eu_4.add_df(eu_4_df)


###( load dataset 8 )###
eu_8_df = pd.read_csv(
    "https://ipyvizzu.vizzuhq.com/0.17/assets/data/chart_types_eu_data_8.csv",
    dtype={
        "Year": str, 
        "Timeseries": str
    },
)
data_eu_8 = Data()
data_eu_8.add_df(eu_8_df)



###( load dataset Music Industry History - 1 )###
mih_1_df = pd.read_csv(
    "https://ipyvizzu.vizzuhq.com/0.17/assets/data/music_industry_history_1.csv",
    dtype={
        "Year": str, 
        "Timeseries": str
    },
)
data_mih_1 = Data()
data_mih_1.add_df(mih_1_df)

# %%
###( Sum: 100% Stacked Area )###
### https://ipyvizzu.vizzuhq.com/latest/examples/analytical_operations/sum/area_100percent_stacked/

chart = Chart()
chart.animate(data_eu_6)
chart.animate(
    Config(
        {
            "channels": {
                "x": "Year",
                "y": ["Value 2 (+)", "Country"],
                "color": "Country",
            },
            "geometry": "area",
            "align": "stretch",
            "title": "Sum: 100% Stacked Area",
        }
    )
)
 
chart.animate(Config({"align": "none"}))
 
chart.feature("tooltip", True)

# %%
###( Sum: Polar Split Area )###
### https://ipyvizzu.vizzuhq.com/latest/examples/analytical_operations/sum/area_polar_split/

chart = Chart()
chart.animate(data_eu_6)
chart.animate(
    Config(
        {
            "channels": {
                "x": "Year",
                "y": {
                    "set": ["Country", "Value 2 (+)"],
                    "range": {"min": "-20%"},
                },
                "color": "Country",
            },
            "geometry": "area",
            "split": True,
            "coordSystem": "polar",
            "title": "Sum: Polar Split Area",
        }
    )
)
 
chart.animate(Config({"split": False}))
 
chart.feature("tooltip", True)

# %%
###( Sum: Polar Stacked Area )###
### https://ipyvizzu.vizzuhq.com/latest/examples/analytical_operations/sum/area_100percent_stacked/

chart = Chart()
chart.animate(data_eu_6)
chart.animate(
    Config(
        {
            "channels": {
                "x": "Year",
                "y": ["Value 2 (+)", "Country"],
                "color": "Country",
            },
            "geometry": "area",
            "coordSystem": "polar",
            "title": "Sum: Polar Stacked Area",
        }
    )
)
 
chart.animate(
    Config({"channels": {"y": "Value 2 (+)", "color": None}})
)
 
chart.feature("tooltip", True)

# %%
###( Sum: Split Area )###
### https://ipyvizzu.vizzuhq.com/latest/examples/analytical_operations/sum/area_split/

chart = Chart()
chart.animate(data_eu_6)
chart.animate(
    Config(
        {
            "channels": {
                "x": "Year",
                "y": ["Value 2 (+)", "Country"],
                "color": "Country",
            },
            "geometry": "area",
            "split": True,
            "title": "Sum: Split Area",            
        }
    )
)
 
chart.animate(Config({"split": False}))
 
chart.feature("tooltip", True)

# %%
###( Sum: Stacked Area )###
### https://ipyvizzu.vizzuhq.com/latest/examples/analytical_operations/sum/area_stacked/

chart = Chart()
chart.animate(data_eu_6)
chart.animate(
    Config(
        {
            "channels": {
                "x": "Year",
                "y": ["Value 2 (+)", "Country"],
                "color": "Country",
            },
            "geometry": "area",
            "title": "Sum: Stacked Area",          
        }
    )
)
 
chart.animate(
    Config({"channels": {"y": "Value 2 (+)", "color": None}})
)
 
chart.feature("tooltip", True)

# %%
###( Sum: Bubble )###
### https://ipyvizzu.vizzuhq.com/latest/examples/analytical_operations/sum/bubble/

chart = Chart()
chart.animate(data_eu)
chart.animate(
    Config(
        {
            "channels": {
                "color": "Joy factors",
                "size": "Value 2 (+)",
                "label": "Country_code",
            },
            "geometry": "circle",
            "title": "Sum: Bubble",               
        }
    )
)
 
chart.animate(
    Config({"channels": {"size": ["Country_code", "Value 2 (+)"]}})
)

# %%
###( Sum: Bubble to Column )###
### https://ipyvizzu.vizzuhq.com/latest/examples/analytical_operations/sum/bubble_to_column/

chart = Chart()
chart.animate(data_eu)
chart.animate(
    Config(
        {
            "channels": {
                "color": "Joy factors",
                "label": "Country_code",
                "size": ["Country_code", "Value 2 (+)"],
            },
            "geometry": "circle",
            "title": "Sum: Bubble to Column",   
        }
    )
)
 
chart.animate(
    Config(
        {
            "channels": {
                "x": "Joy factors",
                "y": ["Country_code", "Value 2 (+)"],
                "label": None,
                "size": None,
            },
            "geometry": "rectangle",
        }
    )
)
 
chart.animate(
    Config({"channels": {"y": "Value 2 (+)", "label": "Value 2 (+)"}})
)

# %%
###( Sum: Bubble to Coxcomb )###
### https://ipyvizzu.vizzuhq.com/latest/examples/analytical_operations/sum/bubble_to_coxcomb/

chart = Chart()
chart.animate(data_eu)
chart.animate(
    Config(
        {
            "channels": {
                "color": "Joy factors",
                "label": "Country_code",
                "size": ["Country_code", "Value 2 (+)"],
            },
            "geometry": "circle",
            "title": "Sum: Bubble to Coxcomb", 
        }
    )
)

chart.animate(
    Config(
        {
            "channels": {
                "x": "Joy factors",
                "y": ["Country_code", "Value 2 (+)"],
                "label": None,
                "size": None,
            },
            "geometry": "rectangle",
            "coordSystem": "polar",

        }
    ),
    Style({"plot": {"marker": {"rectangleSpacing": "0em"}}}),
)

chart.animate(
    Config({"channels": {"y": "Value 2 (+)", "label": "Value 2 (+)"}})
)

# %%
###( Sum: Bubble to Radial )###
### https://ipyvizzu.vizzuhq.com/latest/examples/analytical_operations/sum/bubble_to_radial/

chart = Chart()
chart.animate(data_eu)
chart.animate(
    Config(
        {
            "channels": {
                "color": "Joy factors",
                "label": "Country_code",
                "size": ["Country_code", "Value 2 (+)"],
            },
            "geometry": "circle",
            "title": "Sum: Bubble to Radial",
        }
    )
)
 
chart.animate(
    Config(
        {
            "channels": {
                "y": {"set": "Joy factors", "range": {"min": "-30%"}},
                "x": ["Country_code", "Value 2 (+)"],
                "label": None,
                "size": None,
            },
            "geometry": "rectangle",
            "coordSystem": "polar",
            "sort": "byValue",
        }
    )
)
 
chart.animate(
    Config({"channels": {"x": "Value 2 (+)", "label": "Value 2 (+)"}})
)

# %%
###( Sum: Bubble Plot 1 )###
### https://ipyvizzu.vizzuhq.com/latest/examples/analytical_operations/sum/bubbleplot_1/

chart = Chart()
chart.animate(data_eu_6)
chart.animate(
    Config(
        {
            "channels": {
                "x": "Value 1 (+)",
                "y": "Value 3 (+)",
                "size": "Value 2 (+)",
                "color": "Year",
                "label": "Country_code",
            },
            "geometry": "circle",
            "title": "Sum: Bubble Plot 1",
        }
    )
)
 
chart.animate(Config({"channels": {"label": "Year"}}))

chart.feature("tooltip", True)

# %%
###( Sum: Bubble Plot 2 )###
### https://ipyvizzu.vizzuhq.com/latest/examples/analytical_operations/sum/bubbleplot_2/

chart = Chart()
chart.animate(data_eu)
chart.animate(
    Config(
        {
            "channels": {
                "x": ["Joy factors", "Value 6 (+/-)"],
                "y": "Value 5 (+/-)",
                "color": "Joy factors",
                "size": "Value 2 (+)",
                "label": "Country_code",
            },
            "geometry": "circle",
            "title": "Sum: Bubble Plot 2",
        }
    )
)
 
chart.animate(
    Config(
        {
            "channels": {
                "x": ["Country_code", "Value 2 (+)"],
                "y": "Joy factors",
                "label": None,
            },
            "geometry": "rectangle",
            "orientation": "vertical",
        }
    )
)
 
chart.animate(
    Config({"channels": {"x": "Value 2 (+)", "label": "Value 2 (+)"}})
)

# %%
###( Sum: Bubble Plot to Radial )###
### https://ipyvizzu.vizzuhq.com/latest/examples/analytical_operations/sum/bubbleplot_to_radial/

chart = Chart()
chart.animate(data_eu)
chart.animate(
    Config(
        {
            "channels": {
                "x": ["Joy factors", "Value 6 (+/-)"],
                "y": "Value 5 (+/-)",
                "color": "Joy factors",
                "size": "Value 2 (+)",
                "noop": "Country_code",
            },
            "geometry": "circle",
            "title": "Sum: Bubble Plot to Radial",
        }
    ),
    Style({"plot": {"marker": {"guides": {"color": "#ffffff00"}}}}),
)
 
chart.animate(
    Config(
        {
            "channels": {
                "x": ["Country_code", "Value 2 (+)"],
                "y": {"set": "Joy factors", "range": {"min": "-30%"}},
                "noop": None,
            },
            "geometry": "rectangle",
            "orientation": "vertical",
            "coordSystem": "polar",
        }
    )
)
 
chart.animate(
    Config({"channels": {"x": "Value 2 (+)", "label": "Value 2 (+)"}})
)

# %%
###( Sum: Column 1 )###
### https://ipyvizzu.vizzuhq.com/latest/examples/analytical_operations/sum/column_1/

chart = Chart()
chart.animate(data_eu_8)
chart.animate(
    Config(
        {
            "channels": {
                "x": "Country",
                "y": "Value 2 (+)",
                "label": "Value 2 (+)",
            },
            "title": "Sum: Column 1",
        }
    )
)
 
chart.animate(
    Config(
        {
            "channels": {
                "x": None,
                "y": ["Country", "Value 2 (+)"],
                "color": "Country",
            }
        }
    )
)
 
chart.feature("tooltip", True)

# %%
###( Sum: 100% Stacked Column )###
### https://ipyvizzu.vizzuhq.com/latest/examples/analytical_operations/sum/column_100percent_stacked/

chart = Chart()
chart.animate(data_eu_8)
chart.animate(
    Config(
        {
            "channels": {
                "x": "Year",
                "y": ["Country", "Value 2 (+)"],
                "color": "Country",
            },
            "align": "stretch",
            "title": "Sum: 100% Stacked Column",
        }
    )
)
 
chart.animate(Config({"align": "none"}))
 
chart.feature("tooltip", True)

# %%
###( Sum: Column 2 )###
### https://ipyvizzu.vizzuhq.com/latest/examples/analytical_operations/sum/column_2/

chart = Chart()
chart.animate(data_eu_8)
chart.animate(
    Config(
        {
            "channels": {
                "x": "Country",
                "y": "Value 2 (+)",
                "label": "Value 2 (+)",
            },
            "title": "Sum: Column 2 ",
        }
    )
)
 
chart.animate(Config({"channels": {"x": None}}))
 
chart.feature("tooltip", True)

# %%
###( Sum: Grouped Column )###
### https://ipyvizzu.vizzuhq.com/latest/examples/analytical_operations/sum/column_groupped/

chart = Chart()
chart.animate(data_eu_6)
chart.animate(
    Config(
        {
            "channels": {
                "x": ["Year", "Country"],
                "y": "Value 2 (+)",
                "color": "Country",
            },
            "title": "Sum: Grouped Column",
        }
    )
)
 
chart.animate(
    Config(
        {
            "channels": {
                "x": "Year",
                "y": ["Country", "Value 2 (+)"],
                "color": "Country",
            }
        }
    )
)
 
chart.feature("tooltip", True)

# %%
###( Sum: Split Stacked Column )###
### https://ipyvizzu.vizzuhq.com/latest/examples/analytical_operations/sum/column_split_stacked/

chart = Chart()
chart.animate(data_eu_8)
chart.animate(
    Config(
        {
            "channels": {
                "x": "Year",
                "y": ["Country", "Value 2 (+)"],
                "color": "Country",
                "label": "Value 2 (+)",
            },
            "split": True,
            "title": "Sum: Split Stacked Column",
        }
    ),
    Style(
        {
            "plot": {
                "marker": {
                    "label": {"position": "top", "fontSize": "0.6em"}
                }
            }
        }
    ),
)
 
chart.animate(Config({"channels": {"label": None}, "split": False}))
 
chart.feature("tooltip", True)

# %%
###( Sum: Stacked Column 1 )###
### https://ipyvizzu.vizzuhq.com/latest/examples/analytical_operations/sum/column_stacked_1/

chart = Chart()
chart.animate(data_eu_8)
chart.animate(
    Config(
        {
            "channels": {
                "x": "Country",
                "y": ["Value 2 (+)", "Joy factors"],
                "color": "Joy factors",
                "label": "Value 2 (+)",
            },
            "title": "Sum: Stacked Column 1",
        }
    )
)
 
chart.animate(
    Config({"channels": {"y": "Value 2 (+)", "color": None}})
)
 
chart.feature("tooltip", True)

# %%
###( Sum: Stacked Column 2 )###
### https://ipyvizzu.vizzuhq.com/latest/examples/analytical_operations/sum/column_stacked_2/

chart = Chart()
chart.animate(data_eu)
chart.animate(
    Config(
        {
            "channels": {
                "x": "Year",
                "y": ["Joy factors", "Value 2 (+)"],
                "color": "Joy factors",
            },
            "title": "Sum: Stacked Column 2",
        }
    ),
    Style(
        {
            "plot": {
                "marker": {
                    "colorPalette": "#ef675aFF #6d8cccFF #e6cf99FF #9c50abFF"
                }
            }
        }
    ),
)
 
chart.animate(
    Config(
        {
            "channels": {
                "x": "Value 2 (+)",
                "y": ["Joy factors"],
                "label": "Value 2 (+)",
            }
        }
    )
)

# %%
###( Sum: Column to Bar )###
### https://ipyvizzu.vizzuhq.com/latest/examples/analytical_operations/sum/column_to_bar/

chart = Chart()
chart.animate(data_eu_8)
chart.animate(
    Config(
        {
            "channels": {
                "x": "Country",
                "y": "Value 2 (+)",
                "label": "Value 2 (+)",
            },
            "title": "Sum: Column to Bar",
        }
    )
)
 
chart.animate(
    Config(
        {
            "channels": {"x": "Value 2 (+)", "y": None},
            "orientation": "vertical",
        }
    )
)
 
chart.feature("tooltip", True)

# %%
###( Sum: Column to Waterfall )###
### https://ipyvizzu.vizzuhq.com/latest/examples/analytical_operations/sum/column_to_waterfall/

chart = Chart()
chart.animate(data_eu_6)
chart.animate(
    Config(
        {
            "channels": {
                "x": "Year",
                "y": "Value 5 (+/-)",
                "color": {
                    "set": "Value 5 (+/-)",
                    "range": {"min": "-45", "max": "45"},
                },
                "noop": "Country",
                "label": "Value 5 (+/-)",
            },
            "legend": "color",
            "title": "Sum: Column to Bar",
        }
    ),
    Style(
        {
            "plot": {
                "marker": {
                    "colorGradient": "#ac1727 0,#e36c56 0.15,#f4b096 0.35,#d5d7d9 0.5,#9fbffa 0.65,#6389ec 0.85,#3d51b8 1",
                    "label": {"position": "top"},
                }
            }
        }
    ),
)
 
chart.animate(Config({"channels": {"y": ["Year", "Value 5 (+/-)"]}}))

# %%
###( Sum: Coxcomb 1 )###
### https://ipyvizzu.vizzuhq.com/latest/examples/analytical_operations/sum/coxcomb_1/

chart = Chart()
chart.animate(data_eu_8)
chart.animate(
    Config(
        {
            "channels": {
                "x": "Country",
                "y": ["Value 2 (+)", "Joy factors"],
                "color": "Joy factors",
            },
            "coordSystem": "polar",
            "title": "Sum: Coxcomb 1",
        }
    ),
    Style({"plot": {"marker": {"rectangleSpacing": "0.1em"}}}),
)
 
chart.animate(
    Config(
        {
            "channels": {
                "y": "Value 2 (+)",
                "color": None,
                "label": "Value 2 (+)",
            }
        }
    )
)
 
chart.feature("tooltip", True)

# %%
###( Sum: Coxcomb 2 )###
### https://ipyvizzu.vizzuhq.com/latest/examples/analytical_operations/sum/coxcomb_2/

chart.animate(
    Config(
        {
            "channels": {
                "x": "Year",
                "y": ["Joy factors", "Value 2 (+)"],
                "color": "Joy factors",
            },
            "coordSystem": "polar",
            "title": "Sum: Coxcomb 2",
        }
    ),
    Style(
        {
            "plot": {
                "marker": {
                    "colorPalette": "#ef675aFF #6d8cccFF #e6cf99FF #9c50abFF",
                    "rectangleSpacing": "0.1em",
                }
            }
        }
    ),
)
 
chart.animate(
    Config(
        {
            "channels": {
                "x": "Value 2 (+)",
                "y": {"set": "Joy factors", "range": {"min": "-30%"}},
                "label": "Value 2 (+)",
            }
        }
    ),
    Style({"plot": {"marker": {"rectangleSpacing": None}}}),
)

# %%
###( Sum: Split Coxcomb )###
### https://ipyvizzu.vizzuhq.com/latest/examples/analytical_operations/sum/column_groupped/

chart = Chart()
chart.animate(data_eu_8)
chart.animate(
    Config(
        {
            "channels": {
                "x": "Year",
                "y": {
                    "set": ["Country", "Value 2 (+)"],
                    "range": {"min": "-20%"},
                },
                "color": "Country",
            },
            "split": True,
            "coordSystem": "polar",
            "title": "Sum: Split Coxcomb",
        }
    ),
    Style({"plot": {"marker": {"rectangleSpacing": "0.1em"}}}),
)
 
chart.animate(Config({"split": False}))
 
chart.feature("tooltip", True)

# %%
###( Sum: Dot Plot )###
### https://ipyvizzu.vizzuhq.com/latest/examples/analytical_operations/sum/dotplot/

chart = Chart()
chart.animate(data_eu_8)
chart.animate(
    Config(
        {
            "channels": {
                "x": "Year",
                "y": "Value 2 (+)",
                "color": "Country",
            },
            "geometry": "circle",
            "title": "Sum: Dot Plot",
        }
    )
)
 
chart.animate(
    Config(
        {
            "channels": {"y": ["Country", "Value 2 (+)"]},
            "geometry": "rectangle",
        }
    )
)
 
chart.feature("tooltip", True)

# %%
###( Sum: Line 1 )###
### https://ipyvizzu.vizzuhq.com/latest/examples/analytical_operations/sum/line_1/

chart = Chart()
chart.animate(data_eu_6)
chart.animate(
    Config(
        {
            "channels": {
                "x": "Year",
                "y": "Value 2 (+)",
                "color": "Country",
            },
            "geometry": "line",
            "title": "Sum: Line 1",
        }
    )
)
 
chart.animate(
    Config(
        {
            "channels": {"y": ["Country", "Value 2 (+)"]},
            "geometry": "area",
        }
    )
)
 
chart.feature("tooltip", True)

# %%
###( Sum: Line 2 )###
### https://ipyvizzu.vizzuhq.com/latest/examples/analytical_operations/sum/line_2/

chart = Chart()
chart.animate(data_eu_6)
chart.animate(
    Config(
        {
            "channels": {
                "x": "Year",
                "y": "Value 2 (+)",
                "color": "Country",
            },
            "geometry": "line",
            "title": "Sum: Line 2",
        }
    )
)
 
chart.animate(Config({"channels": {"color": None}}))
 
chart.feature("tooltip", True)

# %%
###( Sum: Polar Line 1 )###
### https://ipyvizzu.vizzuhq.com/latest/examples/analytical_operations/sum/line_polar_1/

chart = Chart()
chart.animate(data_eu_6)
chart.animate(
    Config(
        {
            "channels": {
                "x": "Year",
                "y": "Value 2 (+)",
                "color": "Country",
            },
            "geometry": "line",
            "coordSystem": "polar",
            "title": "Sum: Polar Line 1 ",
        }
    )
)
 
chart.animate(Config({"channels": {"color": None}}))
 
chart.feature("tooltip", True)

# %%
###( Sum: Polar Line 2 )###
### https://ipyvizzu.vizzuhq.com/latest/examples/analytical_operations/sum/line_polar_2/

chart = Chart()
chart.animate(data_eu_6)
chart.animate(
    Config(
        {
            "channels": {
                "x": "Year",
                "y": {"set": "Value 2 (+)", "range": {"min": "-20%"}},
                "color": "Country",
            },
            "geometry": "line",
            "coordSystem": "polar",
            "title": "Sum: Polar Line 2",
        }
    )
)
 
chart.animate(
    Config(
        {
            "channels": {"y": ["Country", "Value 2 (+)"]},
            "geometry": "area",
        }
    )
)
 
chart.feature("tooltip", True)

# %%
###( Sum: Scatter Plot )###
### https://ipyvizzu.vizzuhq.com/latest/examples/analytical_operations/sum/scatterplot/

chart = Chart()
chart.animate(data_eu_6)
chart.animate(
    Config(
        {
            "channels": {
                "x": "Value 1 (+)",
                "y": "Value 3 (+)",
                "color": "Country",
                "label": "Year",
            },
            "geometry": "circle",
            "title": "Sum: Scatter Plot",
        }
    )
)
 
chart.animate(Config({"channels": {"label": "Country"}}))
 
chart.feature("tooltip", True)

# %%
###( Sum: Polar Scatter Plot )###
### https://ipyvizzu.vizzuhq.com/latest/examples/analytical_operations/sum/scatterplot_polar/

chart = Chart()
chart.animate(data_eu_8)
chart.animate(
    Config(
        {
            "channels": {
                "x": "Year",
                "y": "Value 2 (+)",
                "color": "Country",
            },
            "geometry": "circle",
            "coordSystem": "polar",
            "title": "Sum: Polar Scatter Plot",
        }
    ),
    Style(
        {
            "plot": {
                "marker": {
                    "rectangleSpacing": "0.1em",
                    "label": {"position": "top", "fontSize": "0.6em"},
                }
            }
        }
    ),
)
 
chart.animate(
    Config(
        {
            "channels": {"y": ["Country", "Value 2 (+)"]},
            "geometry": "rectangle",
        }
    )
)
 
chart.feature("tooltip", True)
chart.feature("tooltip", True)

# %%
###( Sum: Stacked Stream )###
### https://ipyvizzu.vizzuhq.com/latest/examples/analytical_operations/sum/stream_stacked/

chart = Chart()
chart.animate(data_mih_1)
method = """
            const year = parseFloat(event.detail.text)
            if (!event.detail.text.includes('$') && !isNaN(year) && year % 5 !== 0)
                event.preventDefault()
        """
handler = chart.on("plot-axis-label-draw", method)
 
chart.animate(
    Config(
        {
            "channels": {
                "x": "Year",
                "y": ["Revenue", "Format"],
                "color": "Format",
            },
            "geometry": "area",
            "align": "center",
        }
    ),
    Style(
        {"plot": {"yAxis": {"label": {"numberScale": "K, M, B, T"}}}}
    ),
)
 
chart.animate(Config({"split": True}))
 
chart.animate(
    Config(
        {
            "channels": {"y": ["Revenue", "Year"], "x": ["Format"]},
            "geometry": "rectangle",
            "align": "none",
            "split": False,
            "sort": "byValue",
            "reverse": True,
        }
    )
)
 
chart.feature("tooltip", True)

# %%
###( Sum: Treemap )###
### https://ipyvizzu.vizzuhq.com/latest/examples/analytical_operations/sum/treemap/

chart = Chart()
chart.animate(data_eu)
chart.animate(
    Config(
        {
            "channels": {
                "size": "Value 2 (+)",
                "noop": "Country_code",
                "color": "Joy factors",
                "label": "Country_code",
            }
        }
    )
)
 
chart.animate(
    Config({"channels": {"size": ["Country_code", "Value 2 (+)"]}})
)

# %%
###( END )###
