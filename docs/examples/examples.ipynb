# %% [markdown]
# # ipyvizzu examples
#
# ## Preset charts
# <div>
# <div style="float:left"><a href="presets/02_C_R_column.html"><img src="https://github.com/vizzuhq/vizzu-lib-doc/raw/main/docs/latest/content/examples/presets/02_C_R_column.png"></a></div>
# <div style="float:left"><a href="presets/03_C_R_grouped_column_negative.html"><img src="https://github.com/vizzuhq/vizzu-lib-doc/raw/main/docs/latest/content/examples/presets/03_C_R_grouped_column_negative.png"></a></div>
# <div style="float:left"><a href="presets/04_C_R_stacked_column.html"><img src="https://github.com/vizzuhq/vizzu-lib-doc/raw/main/docs/latest/content/examples/presets/04_C_R_stacked_column.png"></a></div>
# <div style="float:left"><a href="presets/05_C_R_splitted_column.html"><img src="https://github.com/vizzuhq/vizzu-lib-doc/raw/main/docs/latest/content/examples/presets/05_C_R_splitted_column.png"></a></div>
# <div style="float:left"><a href="presets/06_C_R_percentage_column.html"><img src="https://github.com/vizzuhq/vizzu-lib-doc/raw/main/docs/latest/content/examples/presets/06_C_R_percentage_column.png"></a></div>
# <div style="float:left"><a href="presets/08_C_R_waterfall.html"><img src="https://github.com/vizzuhq/vizzu-lib-doc/raw/main/docs/latest/content/examples/presets/08_C_R_waterfall.png"></a></div>
# <div style="float:left"><a href="presets/09_C_R_stacked_mekko.html"><img src="https://github.com/vizzuhq/vizzu-lib-doc/raw/main/docs/latest/content/examples/presets/09_C_R_stacked_mekko.png"></a></div>
# <div style="float:left"><a href="presets/10_C_R_marimekko.html"><img src="https://github.com/vizzuhq/vizzu-lib-doc/raw/main/docs/latest/content/examples/presets/10_C_R_marimekko.png"></a></div>
# <div style="float:left"><a href="presets/13_C_R_bar_negative.html"><img src="https://github.com/vizzuhq/vizzu-lib-doc/raw/main/docs/latest/content/examples/presets/13_C_R_bar_negative.png"></a></div>
# <div style="float:left"><a href="presets/14_C_R_grouped_bar_negative.html"><img src="https://github.com/vizzuhq/vizzu-lib-doc/raw/main/docs/latest/content/examples/presets/14_C_R_grouped_bar_negative.png"></a></div>
# <div style="float:left"><a href="presets/15_C_R_stacked_bar.html"><img src="https://github.com/vizzuhq/vizzu-lib-doc/raw/main/docs/latest/content/examples/presets/15_C_R_stacked_bar.png"></a></div>
# <div style="float:left"><a href="presets/16_C_R_splitted_bar.html"><img src="https://github.com/vizzuhq/vizzu-lib-doc/raw/main/docs/latest/content/examples/presets/16_C_R_splitted_bar.png"></a></div>
# <div style="float:left"><a href="presets/17_C_R_percentage_bar.html"><img src="https://github.com/vizzuhq/vizzu-lib-doc/raw/main/docs/latest/content/examples/presets/17_C_R_percentage_bar.png"></a></div>
# <div style="float:left"><a href="presets/20_C_C_lollipop_chart.html"><img src="https://github.com/vizzuhq/vizzu-lib-doc/raw/main/docs/latest/content/examples/presets/20_C_C_lollipop_chart.png"></a></div>
# <div style="float:left"><a href="presets/22_C_C_scatter.html"><img src="https://github.com/vizzuhq/vizzu-lib-doc/raw/main/docs/latest/content/examples/presets/22_C_C_scatter.png"></a></div>
# <div style="float:left"><a href="presets/24_C_C_bubbleplot.html"><img src="https://github.com/vizzuhq/vizzu-lib-doc/raw/main/docs/latest/content/examples/presets/24_C_C_bubbleplot.png"></a></div>
# <div style="float:left"><a href="presets/27_C_A_area_negative.html"><img src="https://github.com/vizzuhq/vizzu-lib-doc/raw/main/docs/latest/content/examples/presets/27_C_A_area_negative.png"></a></div>
# <div style="float:left"><a href="presets/28_C_A_stacked_area.html"><img src="https://github.com/vizzuhq/vizzu-lib-doc/raw/main/docs/latest/content/examples/presets/28_C_A_stacked_area.png"></a></div>
# <div style="float:left"><a href="presets/29_C_A_percentage_area.html"><img src="https://github.com/vizzuhq/vizzu-lib-doc/raw/main/docs/latest/content/examples/presets/29_C_A_percentage_area.png"></a></div>
# <div style="float:left"><a href="presets/31_C_A_splitted_area.html"><img src="https://github.com/vizzuhq/vizzu-lib-doc/raw/main/docs/latest/content/examples/presets/31_C_A_splitted_area.png"></a></div>
# <div style="float:left"><a href="presets/32_C_A_stream.html"><img src="https://github.com/vizzuhq/vizzu-lib-doc/raw/main/docs/latest/content/examples/presets/32_C_A_stream.png"></a></div>
# <div style="float:left"><a href="presets/33_C_A_vertical_stream.html"><img src="https://github.com/vizzuhq/vizzu-lib-doc/raw/main/docs/latest/content/examples/presets/33_C_A_vertical_stream.png"></a></div>
# <div style="float:left"><a href="presets/34_C_A_violin.html"><img src="https://github.com/vizzuhq/vizzu-lib-doc/raw/main/docs/latest/content/examples/presets/34_C_A_violin.png"></a></div>
# <div style="float:left"><a href="presets/35_C_A_vertical_violin.html"><img src="https://github.com/vizzuhq/vizzu-lib-doc/raw/main/docs/latest/content/examples/presets/35_C_A_vertical_violin.png"></a></div>
# <div style="float:left"><a href="presets/38_C_L_line.html"><img src="https://github.com/vizzuhq/vizzu-lib-doc/raw/main/docs/latest/content/examples/presets/38_C_L_line.png"></a></div>
# <div style="float:left"><a href="presets/39_C_L_vertical_line.html"><img src="https://github.com/vizzuhq/vizzu-lib-doc/raw/main/docs/latest/content/examples/presets/39_C_L_vertical_line.png"></a></div>
# <div style="float:left"><a href="presets/40_P_R_pie.html"><img src="https://github.com/vizzuhq/vizzu-lib-doc/raw/main/docs/latest/content/examples/presets/40_P_R_pie.png"></a></div>
# <div style="float:left"><a href="presets/42_P_R_polar_column.html"><img src="https://github.com/vizzuhq/vizzu-lib-doc/raw/main/docs/latest/content/examples/presets/42_P_R_polar_column.png"></a></div>
# <div style="float:left"><a href="presets/42a_P_R_polar_stacked_column.html"><img src="https://github.com/vizzuhq/vizzu-lib-doc/raw/main/docs/latest/content/examples/presets/42a_P_R_polar_stacked_column.png"></a></div>
# <div style="float:left"><a href="presets/44_P_R_variable_radius_pie_chart.html"><img src="https://github.com/vizzuhq/vizzu-lib-doc/raw/main/docs/latest/content/examples/presets/44_P_R_variable_radius_pie_chart.png"></a></div>
# <div style="float:left"><a href="presets/49_P_R_radial_bar.html"><img src="https://github.com/vizzuhq/vizzu-lib-doc/raw/main/docs/latest/content/examples/presets/49_P_R_radial_bar.png"></a></div>
# <div style="float:left"><a href="presets/50_P_R_radial_stacked_bar.html"><img src="https://github.com/vizzuhq/vizzu-lib-doc/raw/main/docs/latest/content/examples/presets/50_P_R_radial_stacked_bar.png"></a></div>
# <div style="float:left"><a href="presets/51_P_R_donut.html"><img src="https://github.com/vizzuhq/vizzu-lib-doc/raw/main/docs/latest/content/examples/presets/51_P_R_donut.png"></a></div>
# <div style="float:left"><a href="presets/52_P_R_nested_donut.html"><img src="https://github.com/vizzuhq/vizzu-lib-doc/raw/main/docs/latest/content/examples/presets/52_P_R_nested_donut.png"></a></div>
# <div style="float:left"><a href="presets/53_P_C_polar_scatter.html"><img src="https://github.com/vizzuhq/vizzu-lib-doc/raw/main/docs/latest/content/examples/presets/53_P_C_polar_scatter.png"></a></div>
# <div style="float:left"><a href="presets/56_P_A_polar_line.html"><img src="https://github.com/vizzuhq/vizzu-lib-doc/raw/main/docs/latest/content/examples/presets/56_P_A_polar_line.png"></a></div>
# <div style="float:left"><a href="presets/58_W_R_treemap.html"><img src="https://github.com/vizzuhq/vizzu-lib-doc/raw/main/docs/latest/content/examples/presets/58_W_R_treemap.png"></a></div>
# <div style="float:left"><a href="presets/59_W_R_stacked_treemap.html"><img src="https://github.com/vizzuhq/vizzu-lib-doc/raw/main/docs/latest/content/examples/presets/59_W_R_stacked_treemap.png"></a></div>
# <div style="float:left"><a href="presets/60_W_R_heatmap.html"><img src="https://github.com/vizzuhq/vizzu-lib-doc/raw/main/docs/latest/content/examples/presets/60_W_R_heatmap.png"></a></div>
# <div style="float:left"><a href="presets/61_W_R_bubble_chart.html"><img src="https://github.com/vizzuhq/vizzu-lib-doc/raw/main/docs/latest/content/examples/presets/61_W_R_bubble_chart.png"></a></div>
# <div style="float:left"><a href="presets/62_W_R_stacked_bubble.html"><img src="https://github.com/vizzuhq/vizzu-lib-doc/raw/main/docs/latest/content/examples/presets/62_W_R_stacked_bubble.png"></a></div>
# </div>
# <div style="clear:both"></div>
#
# ## Static charts
# <div>
# <div style="float:left"><a href="static/bar_rectangle_negative_1dis_1con.html"><img src="https://github.com/vizzuhq/vizzu-lib-doc/raw/main/docs/latest/content/examples/static/bar_rectangle_negative_1dis_1con.png"></a></div>
# <div style="float:left"><a href="static/line_negative_1dis_1con.html"><img src="https://github.com/vizzuhq/vizzu-lib-doc/raw/main/docs/latest/content/examples/static/line_negative_1dis_1con.png"></a></div>
# <div style="float:left"><a href="static/marimekko_rectangle_2dis_2con.html"><img src="https://github.com/vizzuhq/vizzu-lib-doc/raw/main/docs/latest/content/examples/static/marimekko_rectangle_2dis_2con.png"></a></div>
# <div style="float:left"><a href="static/line_negative_2dis_1con.html"><img src="https://github.com/vizzuhq/vizzu-lib-doc/raw/main/docs/latest/content/examples/static/line_negative_2dis_1con.png"></a></div>
# <div style="float:left"><a href="static/stacked_area_2dis_1con.html"><img src="https://github.com/vizzuhq/vizzu-lib-doc/raw/main/docs/latest/content/examples/static/stacked_area_2dis_1con.png"></a></div>
# <div style="float:left"><a href="static/mekko_rectangle_1dis_2con.html"><img src="https://github.com/vizzuhq/vizzu-lib-doc/raw/main/docs/latest/content/examples/static/mekko_rectangle_1dis_2con.png"></a></div>
# <div style="float:left"><a href="static/histogram_rectangle_negative_1dis_1con.html"><img src="https://github.com/vizzuhq/vizzu-lib-doc/raw/main/docs/latest/content/examples/static/histogram_rectangle_negative_1dis_1con.png"></a></div>
# <div style="float:left"><a href="static/dotplot_circle_negative_1dis_1con.html"><img src="https://github.com/vizzuhq/vizzu-lib-doc/raw/main/docs/latest/content/examples/static/dotplot_circle_negative_1dis_1con.png"></a></div>
# <div style="float:left"><a href="static/waterfall_rectangle_negative_1dis_1con.html"><img src="https://github.com/vizzuhq/vizzu-lib-doc/raw/main/docs/latest/content/examples/static/waterfall_rectangle_negative_1dis_1con.png"></a></div>
# <div style="float:left"><a href="static/scatterplot_circle_negative_2dis_3con.html"><img src="https://github.com/vizzuhq/vizzu-lib-doc/raw/main/docs/latest/content/examples/static/scatterplot_circle_negative_2dis_3con.png"></a></div>
# <div style="float:left"><a href="static/stacked_mekko_rectangle_2dis_2con.html"><img src="https://github.com/vizzuhq/vizzu-lib-doc/raw/main/docs/latest/content/examples/static/stacked_mekko_rectangle_2dis_2con.png"></a></div>
# <div style="float:left"><a href="static/column_grouped_rectangle_negative_2dis_1con.html"><img src="https://github.com/vizzuhq/vizzu-lib-doc/raw/main/docs/latest/content/examples/static/column_grouped_rectangle_negative_2dis_1con.png"></a></div>
# <div style="float:left"><a href="static/column_stacked_rectangle_1dis_1con.html"><img src="https://github.com/vizzuhq/vizzu-lib-doc/raw/main/docs/latest/content/examples/static/column_stacked_rectangle_1dis_1con.png"></a></div>
# <div style="float:left"><a href="static/area_negative_1dis_1con.html"><img src="https://github.com/vizzuhq/vizzu-lib-doc/raw/main/docs/latest/content/examples/static/area_negative_1dis_1con.png"></a></div>
# <div style="float:left"><a href="static/column_stacked_rectangle_negative_2dis_1con.html"><img src="https://github.com/vizzuhq/vizzu-lib-doc/raw/main/docs/latest/content/examples/static/column_stacked_rectangle_negative_2dis_1con.png"></a></div>
# <div style="float:left"><a href="static/scatterplot_circle_negative_1dis_2con.html"><img src="https://github.com/vizzuhq/vizzu-lib-doc/raw/main/docs/latest/content/examples/static/scatterplot_circle_negative_1dis_2con.png"></a></div>
# <div style="float:left"><a href="static/stream_stacked_area_3dis_1con.html"><img src="https://github.com/vizzuhq/vizzu-lib-doc/raw/main/docs/latest/content/examples/static/stream_stacked_area_3dis_1con.png"></a></div>
# <div style="float:left"><a href="static/NO_spiderweb_line_2dis_1con.html"><img src="https://github.com/vizzuhq/vizzu-lib-doc/raw/main/docs/latest/content/examples/static/NO_spiderweb_line_2dis_1con.png"></a></div>
# <div style="float:left"><a href="static/coxcomb_stacked_rectangle_2dis_1con.html"><img src="https://github.com/vizzuhq/vizzu-lib-doc/raw/main/docs/latest/content/examples/static/coxcomb_stacked_rectangle_2dis_1con.png"></a></div>
# <div style="float:left"><a href="static/radial_rectangle_1dis_1con.html"><img src="https://github.com/vizzuhq/vizzu-lib-doc/raw/main/docs/latest/content/examples/static/radial_rectangle_1dis_1con.png"></a></div>
# <div style="float:left"><a href="static/donut_rectangle_1dis_1con.html"><img src="https://github.com/vizzuhq/vizzu-lib-doc/raw/main/docs/latest/content/examples/static/donut_rectangle_1dis_1con.png"></a></div>
# <div style="float:left"><a href="static/spiderweb_area_1dis_1con.html"><img src="https://github.com/vizzuhq/vizzu-lib-doc/raw/main/docs/latest/content/examples/static/spiderweb_area_1dis_1con.png"></a></div>
# <div style="float:left"><a href="static/spiderweb_line_1dis_1con.html"><img src="https://github.com/vizzuhq/vizzu-lib-doc/raw/main/docs/latest/content/examples/static/spiderweb_line_1dis_1con.png"></a></div>
# <div style="float:left"><a href="static/pie_rectangle_1dis_1con.html"><img src="https://github.com/vizzuhq/vizzu-lib-doc/raw/main/docs/latest/content/examples/static/pie_rectangle_1dis_1con.png"></a></div>
# <div style="float:left"><a href="static/radial_stacked_rectangle_2dis_1con.html"><img src="https://github.com/vizzuhq/vizzu-lib-doc/raw/main/docs/latest/content/examples/static/radial_stacked_rectangle_2dis_1con.png"></a></div>
# <div style="float:left"><a href="static/treemap_rectangle_2dis_2con.html"><img src="https://github.com/vizzuhq/vizzu-lib-doc/raw/main/docs/latest/content/examples/static/treemap_rectangle_2dis_2con.png"></a></div>
# <div style="float:left"><a href="static/treemap_rectangle_1dis_1con.html"><img src="https://github.com/vizzuhq/vizzu-lib-doc/raw/main/docs/latest/content/examples/static/treemap_rectangle_1dis_1con.png"></a></div>
# <div style="float:left"><a href="static/bubble_circle_1dis_2con.html"><img src="https://github.com/vizzuhq/vizzu-lib-doc/raw/main/docs/latest/content/examples/static/bubble_circle_1dis_2con.png"></a></div>
# <div style="float:left"><a href="static/bubble_circle_2dis_2con.html"><img src="https://github.com/vizzuhq/vizzu-lib-doc/raw/main/docs/latest/content/examples/static/bubble_circle_2dis_2con.png"></a></div>
# </div>
# <div style="clear:both"></div>
#
# ## Animated charts
# <div>
# <div style="float:left"><a href="animated/composition_percentage_area_stream_3dis_1con.html"><video nocontrols autoplay muted loop src="https://github.com/vizzuhq/vizzu-lib-doc/raw/main/docs/latest/content/examples/animated/composition_percentage_area_stream_3dis_1con.mp4" type="video/mp4"></video></a></div>
# <div style="float:left"><a href="animated/composition_comparison_pie_coxcomb_column_2dis_2con.html"><video nocontrols autoplay muted loop src="https://github.com/vizzuhq/vizzu-lib-doc/raw/main/docs/latest/content/examples/animated/composition_comparison_pie_coxcomb_column_2dis_2con.mp4" type="video/mp4"></video></a></div>
# <div style="float:left"><a href="animated/composition_percentage_column_stream_3dis_1con.html"><video nocontrols autoplay muted loop src="https://github.com/vizzuhq/vizzu-lib-doc/raw/main/docs/latest/content/examples/animated/composition_percentage_column_stream_3dis_1con.mp4" type="video/mp4"></video></a></div>
# <div style="float:left"><a href="animated/merge_split_area_stream_3dis_1con.html"><video nocontrols autoplay muted loop src="https://github.com/vizzuhq/vizzu-lib-doc/raw/main/docs/latest/content/examples/animated/merge_split_area_stream_3dis_1con.mp4" type="video/mp4"></video></a></div>
# <div style="float:left"><a href="animated/total_element_bubble_2_bar.html"><video nocontrols autoplay muted loop src="https://github.com/vizzuhq/vizzu-lib-doc/raw/main/docs/latest/content/examples/animated/total_element_bubble_2_bar.mp4" type="video/mp4"></video></a></div>
# <div style="float:left"><a href="animated/merge_split_bar.html"><video nocontrols autoplay muted loop src="https://github.com/vizzuhq/vizzu-lib-doc/raw/main/docs/latest/content/examples/animated/merge_split_bar.mp4" type="video/mp4"></video></a></div>
# <div style="float:left"><a href="animated/merge_split_radial_stacked_rectangle_2dis_1con.html"><video nocontrols autoplay muted loop src="https://github.com/vizzuhq/vizzu-lib-doc/raw/main/docs/latest/content/examples/animated/merge_split_radial_stacked_rectangle_2dis_1con.mp4" type="video/mp4"></video></a></div>
# <div style="float:left"><a href="animated/orientation_circle.html"><video nocontrols autoplay muted loop src="https://github.com/vizzuhq/vizzu-lib-doc/raw/main/docs/latest/content/examples/animated/orientation_circle.mp4" type="video/mp4"></video></a></div>
# <div style="float:left"><a href="animated/orientation_marimekko_rectangle_2dis_2con.html"><video nocontrols autoplay muted loop src="https://github.com/vizzuhq/vizzu-lib-doc/raw/main/docs/latest/content/examples/animated/orientation_marimekko_rectangle_2dis_2con.mp4" type="video/mp4"></video></a></div>
# <div style="float:left"><a href="animated/pie_donut2_rectangle_1dis_1con.html"><video nocontrols autoplay muted loop src="https://github.com/vizzuhq/vizzu-lib-doc/raw/main/docs/latest/content/examples/animated/pie_donut2_rectangle_1dis_1con.mp4" type="video/mp4"></video></a></div>
# <div style="float:left"><a href="animated/relationship_comparison_circle_2_bubble_plot.html"><video nocontrols autoplay muted loop src="https://github.com/vizzuhq/vizzu-lib-doc/raw/main/docs/latest/content/examples/animated/relationship_comparison_circle_2_bubble_plot.mp4" type="video/mp4"></video></a></div>
# <div style="float:left"><a href="animated/relationship_total_bubble_plot_column.html"><video nocontrols autoplay muted loop src="https://github.com/vizzuhq/vizzu-lib-doc/raw/main/docs/latest/content/examples/animated/relationship_total_bubble_plot_column.mp4" type="video/mp4"></video></a></div>
# <div style="float:left"><a href="animated/stack_group_area_line.html"><video nocontrols autoplay muted loop src="https://github.com/vizzuhq/vizzu-lib-doc/raw/main/docs/latest/content/examples/animated/stack_group_area_line.mp4" type="video/mp4"></video></a></div>
# <div style="float:left"><a href="animated/stack_group_circle.html"><video nocontrols autoplay muted loop src="https://github.com/vizzuhq/vizzu-lib-doc/raw/main/docs/latest/content/examples/animated/stack_group_circle.mp4" type="video/mp4"></video></a></div>
# <div style="float:left"><a href="animated/stack_group_treemap.html"><video nocontrols autoplay muted loop src="https://github.com/vizzuhq/vizzu-lib-doc/raw/main/docs/latest/content/examples/animated/stack_group_treemap.mp4" type="video/mp4"></video></a></div>
# <div style="float:left"><a href="animated/total_element_bubble_column.html"><video nocontrols autoplay muted loop src="https://github.com/vizzuhq/vizzu-lib-doc/raw/main/docs/latest/content/examples/animated/total_element_bubble_column.mp4" type="video/mp4"></video></a></div>
# <div style="float:left"><a href="animated/total_time_area_column.html"><video nocontrols autoplay muted loop src="https://github.com/vizzuhq/vizzu-lib-doc/raw/main/docs/latest/content/examples/animated/total_time_area_column.mp4" type="video/mp4"></video></a></div>
# <div style="float:left"><a href="animated/treemap_radial.html"><video nocontrols autoplay muted loop src="https://github.com/vizzuhq/vizzu-lib-doc/raw/main/docs/latest/content/examples/animated/treemap_radial.mp4" type="video/mp4"></video></a></div>
# <div style="float:left"><a href="animated/zoom_area.html"><video nocontrols autoplay muted loop src="https://github.com/vizzuhq/vizzu-lib-doc/raw/main/docs/latest/content/examples/animated/zoom_area.mp4" type="video/mp4"></video></a></div>
# <div style="float:left"><a href="animated/composition_percentage_column_3dis_1con.html"><video nocontrols autoplay muted loop src="https://github.com/vizzuhq/vizzu-lib-doc/raw/main/docs/latest/content/examples/animated/composition_percentage_column_3dis_1con.mp4" type="video/mp4"></video></a></div>
# <div style="float:left"><a href="animated/total_time_bar_line.html"><video nocontrols autoplay muted loop src="https://github.com/vizzuhq/vizzu-lib-doc/raw/main/docs/latest/content/examples/animated/total_time_bar_line.mp4" type="video/mp4"></video></a></div>
# </div>
# <div style="clear:both"></div>
#
# ## Data stories
# <div>
# <div style="float:left"><a href="stories/musicformats/musicformats.html"><video nocontrols autoplay muted loop src="https://github.com/vizzuhq/vizzu-lib-doc/raw/main/docs/latest/content/examples/stories/musicformats.mp4" type="video/mp4"></video></a></div>
# </div>
# <div style="clear:both"></div>
#
# Back to the [Table of contents](../doc.html#tutorial)
